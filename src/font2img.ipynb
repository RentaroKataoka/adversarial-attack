# %%
# %run font2img.py ../data/GoogleFonts/test_ttf ../Alphabet.txt ../data/GoogleFonts/test_font2 --binary
# Out:
# EkMukta-Light.ttf             :   0%|          | 0/1203 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# CormorantGaramond-LightItalic.ttf:   0%|          | 1/1203 [00:00<08:03,  2.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# NunitoSans-SemiBoldItalic.ttf :   0%|          | 2/1203 [00:00<07:52,  2.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Mada-SemiBold.ttf             :   0%|          | 3/1203 [00:01<07:18,  2.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# KaiseiOpti-Regular.ttf        :   0%|          | 4/1203 [00:01<06:46,  2.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Dekko-Regular.ttf             :   0%|          | 5/1203 [00:01<06:49,  2.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# ChakraPetch-LightItalic.ttf   :   0%|          | 6/1203 [00:02<06:34,  3.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
